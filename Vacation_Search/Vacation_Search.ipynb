# %% [markdown]
# ## Deliverable 2. Create a Customer Travel Destinations Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import gkey

# Configure gmaps API key
gmaps.configure(api_key=gkey)

import csv

# %%
# 1. Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("../Weather_Database/WeatherPy_database.csv")
city_data_df.head()
# Out:
#              City  Cloudiness Country Current Description  Humidity      Lat  \
# 0  Ribeira Grande           3      PT           clear sky        92  38.5167
# 1         Samarai          98      PG     overcast clouds        83 -10.6167
# 2      Novoagansk         100      RU     overcast clouds        91  61.9449
# 3       Caravelas           2      BR           clear sky        64 -17.7125
# 4       Kavaratti          89      IN     overcast clouds        78  10.5669
#
#         Lng  Max Temp  Wind Speed
# 0  -28.7000     70.45        8.77
# 1  150.6667     79.95       15.30
# 2   76.6625     59.32        6.17
# 3  -39.2481     69.69        6.40
# 4   72.6420     81.99       20.80

# %%
# 2. Prompt the user to enter minimum and maximum temperature criteria 
min_temp = float(input('Min Temp: '))
max_temp = float(input('Max Temp: '))
# Out:
# Min Temp: 75
# Max Temp: 90

# %%
# 3. Filter the city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head(10)
# Out:
#              City  Cloudiness Country Current Description  Humidity      Lat  \
# 1         Samarai          98      PG     overcast clouds        83 -10.6167
# 4       Kavaratti          89      IN     overcast clouds        78  10.5669
# 6   Traverse City           0      US           clear sky        85  44.7631
# 7         Wahiawa          90      US          light rain        73  21.5028
# 11           Hilo          90      US          light rain        78  19.7297
# 14         Vanino         100      RU     overcast clouds        62  49.0869
# 18      Thinadhoo         100      MV     overcast clouds        77   0.5333
# 22         Tadine           0      NC           clear sky        69 -21.5500
# 24        Limbang          65      MY       broken clouds        75   4.7500
# 29           Lamu          58      KE       broken clouds        77  -2.2717
#
#          Lng  Max Temp  Wind Speed
# 1   150.6667     79.95       15.30
# 4    72.6420     81.99       20.80
# 6   -85.6206     75.94        5.55
# 7  -158.0236     88.12       14.97
# 11 -155.0900     80.33        9.22
# 14  140.2543     82.90        4.90
# 18   72.9333     82.15       10.96
# 22  167.8833     77.11        0.60
# 24  115.0000     82.71        1.97
# 29   40.9020     77.22       21.34

# %%
# 4a. Determine if there are any empty rows.
preferred_cities_df.count()
# Out:
# City                   255
# Cloudiness             255
# Country                255
# Current Description    255
# Humidity               255
# Lat                    255
# Lng                    255
# Max Temp               255
# Wind Speed             255
# dtype: int64

# %%
# 4b. Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
clean_df =  preferred_cities_df.dropna()

# %%
# 5a. Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = clean_df[["City", "Country", "Max Temp", "Current Description", "Lat", "Lng"]].copy()

# 5b. Create a new column "Hotel Name"
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#              City Country  Max Temp Current Description      Lat       Lng  \
# 1         Samarai      PG     79.95     overcast clouds -10.6167  150.6667
# 4       Kavaratti      IN     81.99     overcast clouds  10.5669   72.6420
# 6   Traverse City      US     75.94           clear sky  44.7631  -85.6206
# 7         Wahiawa      US     88.12          light rain  21.5028 -158.0236
# 11           Hilo      US     80.33          light rain  19.7297 -155.0900
# 14         Vanino      RU     82.90     overcast clouds  49.0869  140.2543
# 18      Thinadhoo      MV     82.15     overcast clouds   0.5333   72.9333
# 22         Tadine      NC     77.11           clear sky -21.5500  167.8833
# 24        Limbang      MY     82.71       broken clouds   4.7500  115.0000
# 29           Lamu      KE     77.22       broken clouds  -2.2717   40.9020
#
#    Hotel Name
# 1
# 4
# 6
# 7
# 11
# 14
# 18
# 22
# 24
# 29

# %%
# 6a. Set parameters to search for hotels with 5000 meters.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": gkey,
    "location": "48.8566, 2.3522"
}
# Use base URL to search for hotels in Paris.
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
# Make request and get the JSON data from the search.
hotels = requests.get(base_url, params=params).json()

hotels
# Out:
# {'html_attributions': [],
#  'next_page_token': 'Aap_uED1oMqGdjZ3zJbGBXYHEE-OhGkIUQFJOqRLSM4aBOAQkku3W1IHAsZ6So4dHWLO2W72CS6UzZXxrcZroO88c7E_lEZGCSfHSuXSOLCrqMl-OC6Vhf13B8b3cNSovBBrTUZTg8AQkMrwOhkvaniVZxPENqyx8p_cC8oZJ5tzBVu0GTTiUm1ek6RJFBysblKmRe_Wco9ltt2eIYCDHUqXzPNVLq4J8ojsNn-n-FK0qgX0V9espleHEEyEFkSYuMtClOwj1etdFHMSXcvNFhFAw0lzkBF0w37q2FEPfh7-Hv5OXkZk1VazVZTtUDTWF6dH84gp0M-E6PcaVnkXwMpW8Fz-hOJoUU7_mehnEI4Xoixb2JtiC-lZ7WdvMUpC-Bmf5XRgWgwxJMVF656iEhcIDmy0XiuONTRGH3dFt47HguDz3qvbwMBD62l1',
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8581126, 'lng': 2.3529277},
#     'viewport': {'northeast': {'lat': 48.8594393802915,
#       'lng': 2.354352980291503},
#      'southwest': {'lat': 48.8567414197085, 'lng': 2.351655019708499}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Hôtel Duo',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3840,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107554201425443337224">Hôtel Duo</a>'],
#      'photo_reference': 'Aap_uEBghsgYURIBCOQ2OXiHW_6JdzmhUwWP9iD4xo8G8CR5u1WFEfjAjO_3SzPF0u_YmiTbvVb8DEEN_UqlpqPMXhOR1AatKDPoMOR5kAYSg8PrZ_85cnFT55b9oMxrkURnZ38cGblmMAS-z4DO2GtoqyeQP4qiSCwy0jQYBCODtvGepFZG',
#      'width': 5760}],
#    'place_id': 'ChIJWU9CqB1u5kcR5P1F2SMoJmc',
#    'plus_code': {'compound_code': 'V953+65 Paris, France',
#     'global_code': '8FW4V953+65'},
#    'rating': 4.2,
#    'reference': 'ChIJWU9CqB1u5kcR5P1F2SMoJmc',
#    'scope': 'GOOGLE',
#    'types': ['night_club',
#     'spa',
#     'lodging',
#     'bar',
#     'gym',
#     'health',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 284,
#    'vicinity': '11 Rue du Temple, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8582861, 'lng': 2.3464944},
#     'viewport': {'northeast': {'lat': 48.8595495802915,
#       'lng': 2.347780980291502},
#      'southwest': {'lat': 48.8568516197085, 'lng': 2.345083019708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Hôtel Britannique - Paris Centre',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3168,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108984000175492464929">Hôtel Britannique - Paris Centre</a>'],
#      'photo_reference': 'Aap_uEBYUHr2BdzGKR3Ko5yl_Ji7iLB54eDWCiQKKAaIy3w9AdWc2QyE1kJWsPmC9jK4-ry-ziYbSmW2UgP0DbCG4Yo0LCWDDltLxiFS8PzRWSzfpdWWWsgIJOtCRvrU4NfKypraxDyNV-bgF6imh23DJ92b7Sg4M6Eo-9ClzxWb4dQJHD0e',
#      'width': 4752}],
#    'place_id': 'ChIJ-4Siox9u5kcRm9vM6DcMXyU',
#    'plus_code': {'compound_code': 'V85W+8H Paris, France',
#     'global_code': '8FW4V85W+8H'},
#    'rating': 4.6,
#    'reference': 'ChIJ-4Siox9u5kcRm9vM6DcMXyU',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 563,
#    'vicinity': '20 Avenue Victoria, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8606655, 'lng': 2.3469293},
#     'viewport': {'northeast': {'lat': 48.86176813029151,
#       'lng': 2.348251430291502},
#      'southwest': {'lat': 48.85907016970851, 'lng': 2.345553469708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Citadines Les Halles Paris',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 849,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102565262508115704337">Citadines Les Halles Paris (Apart hotel Paris)</a>'],
#      'photo_reference': 'Aap_uEC_nk__QbdE-QWwg96lowKNhCoNyflEkvXgHIRsMapkbi4HoBTch-905NeIadpIoCRP3i085g8CUU39W75k4Wk_U9NVmZz2LcSx2fht5AGbeB5Y94DBsgmM_r_Q8Ld-Pa4rgg6Ae0cajph2L_5_i9vFjEVy60_4yWkCNVetZt-i0xkF',
#      'width': 1280}],
#    'place_id': 'ChIJQ_QDrxhu5kcRJzNxLLEOSfU',
#    'plus_code': {'compound_code': 'V86W+7Q Paris, France',
#     'global_code': '8FW4V86W+7Q'},
#    'rating': 4.1,
#    'reference': 'ChIJQ_QDrxhu5kcRJzNxLLEOSfU',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 824,
#    'vicinity': '4 Rue des Innocents, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8607658, 'lng': 2.3465318},
#     'viewport': {'northeast': {'lat': 48.86205553029149,
#       'lng': 2.347674930291502},
#      'southwest': {'lat': 48.85935756970849, 'lng': 2.344976969708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Novotel Paris Les Halles',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2000,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111815616573299411056">Novotel Paris Les Halles</a>'],
#      'photo_reference': 'Aap_uEBkableq47md9rsRJSIpgy2kQVIJW3uZPEuiHZMqqAroDTSNMZTroPyBNYP1l09VlAQeB8bt_n_JIIwxScf_ZoaL8DvLLmfMtwj6jRQ2ciRfPV0DSlFqJcfR-3mMAE7RBGtY0Jzh7Ul_afHvrqo95jGE3781CGv3g1RZOEZEZo2BNAb',
#      'width': 3000}],
#    'place_id': 'ChIJGW2pNx9u5kcRI3oyL8NG5BQ',
#    'plus_code': {'compound_code': 'V86W+8J Paris, France',
#     'global_code': '8FW4V86W+8J'},
#    'rating': 4.4,
#    'reference': 'ChIJGW2pNx9u5kcRI3oyL8NG5BQ',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2165,
#    'vicinity': '8 Place Marguerite de Navarre, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.86034799999999, 'lng': 2.344054},
#     'viewport': {'northeast': {'lat': 48.8616503302915,
#       'lng': 2.345521080291502},
#      'southwest': {'lat': 48.8589523697085, 'lng': 2.342823119708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Hôtel Ducs de Bourgogne',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1390,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101411638353598558320">Hôtel Ducs de Bourgogne</a>'],
#      'photo_reference': 'Aap_uEAigPCZFeDXmtdQJMQjVZFEQDtyF5sAMM50Q50g1rIE0AQXJhhIAOquBq8p04q49y4k_WEM60S0F5T9Fvdjz0Isc3J_EJKZJ-gt46WHq5HPSNGVnR5WhDo0nzHzgWwwmduPoPt7HzOzv8tamtppFMnXqRaCDsG6mFYlxhIL6VZxg2RS',
#      'width': 2048}],
#    'place_id': 'ChIJifTG5yFu5kcRdnisbwxnAx4',
#    'plus_code': {'compound_code': 'V86V+4J Paris, France',
#     'global_code': '8FW4V86V+4J'},
#    'rating': 4.5,
#    'reference': 'ChIJifTG5yFu5kcRdnisbwxnAx4',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 277,
#    'vicinity': '19 Rue du Pont Neuf, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8555091, 'lng': 2.3408736},
#     'viewport': {'northeast': {'lat': 48.8569076302915,
#       'lng': 2.342319280291502},
#      'southwest': {'lat': 48.8542096697085, 'lng': 2.339621319708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Citadines Saint-Germain-des-Prés Paris (Apart hotel Paris)',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4480,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113188832595116816387">Citadines Saint-Germain-des-Prés Paris</a>'],
#      'photo_reference': 'Aap_uEA17wq6uFk_m_YcNKSqyUJGVcQ1k3s8MAl1ab3lEeXSfb01swbmAvcA_vnBF-YJ59WPC8HW2Pd6zk5i4xfKZA8FS4zQq33umBcHHYCivGmF4whkIod8wL743Osqs0R-oNC9cMYIUnw_2bVv-lpdEKofjpcD03CkVsiUrIt9n59LRuYe',
#      'width': 6720}],
#    'place_id': 'ChIJo5pYcN9x5kcRERXdocMgqmE',
#    'plus_code': {'compound_code': 'V84R+68 Paris, France',
#     'global_code': '8FW4V84R+68'},
#    'rating': 4.3,
#    'reference': 'ChIJo5pYcN9x5kcRERXdocMgqmE',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 674,
#    'vicinity': '53 ter Quai des Grands Augustins, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.86634659999999, 'lng': 2.36064},
#     'viewport': {'northeast': {'lat': 48.86774953029149,
#       'lng': 2.361898330291501},
#      'southwest': {'lat': 48.86505156970849, 'lng': 2.359200369708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Paris France Hôtel',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2673,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102332962500946068613">Paris France Hôtel</a>'],
#      'photo_reference': 'Aap_uEAO59y6rCVQfxc8a7tgmyFgS6R4oPmMLiLGctUwbuLLPMISk5kdukUw1jABjtITy45vyjeAAFwfDc6SmgPgaM1iROuqCo189AtqIM-Yg5scNqaAOaCsA40X7TxATqPrPu0vxG-Y3Ymz46BaTSiUrIiJHXdmYGm8GCBt9NOU4nA0uYye',
#      'width': 3463}],
#    'place_id': 'ChIJhXWLZg9u5kcRDVyqoZYgcmg',
#    'plus_code': {'compound_code': 'V986+G7 Paris, France',
#     'global_code': '8FW4V986+G7'},
#    'rating': 4.3,
#    'reference': 'ChIJhXWLZg9u5kcRDVyqoZYgcmg',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 379,
#    'vicinity': '72 Rue de Turbigo, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.86386539999999, 'lng': 2.3325488},
#     'viewport': {'northeast': {'lat': 48.8650759802915,
#       'lng': 2.333775730291502},
#      'southwest': {'lat': 48.8623780197085, 'lng': 2.331077769708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Hotel Regina Louvre',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3700,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109908333790946649027">Hôtel Regina Louvre</a>'],
#      'photo_reference': 'Aap_uEDAfqKfNRaxK7BSQECpEHG2jana-Vg51Crtu5kABl4KOhA-MVJblUn61vGY5T3W3x-ma_yck7fzUGp7o-oAsm8PGkyvFQprvdO9vFyBMf9zSlwS7VkCzerhnoywVK4vk2QyN7UmpzEpsrz-WOh8mpB18KFwnbPBT9wlfjw946kJVJBN',
#      'width': 5550}],
#    'place_id': 'ChIJP_-HCS9u5kcRsj9b1x7Pl8w',
#    'plus_code': {'compound_code': 'V87M+G2 Paris, France',
#     'global_code': '8FW4V87M+G2'},
#    'rating': 4.5,
#    'reference': 'ChIJP_-HCS9u5kcRsj9b1x7Pl8w',
#    'scope': 'GOOGLE',
#    'types': ['lodging',
#     'bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 500,
#    'vicinity': '2 Place des Pyramides, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.84795229999999, 'lng': 2.370869},
#     'viewport': {'northeast': {'lat': 48.8492035302915,
#       'lng': 2.372290080291501},
#      'southwest': {'lat': 48.8465055697085, 'lng': 2.369592119708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'ibis Paris Gare de Lyon Ledru Rollin 12ème',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3000,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110161480967920528437">stefan kebbekus</a>'],
#      'photo_reference': 'Aap_uECCVIXS1tfa7VWpRbI7mRFtlLFSMuuHoR3dhYpfpgqW-J7JeUdl-iSFJmHc_lvShpNkllORLXkdwDFucySO_YTNc4xOzNrgyuoLX0PrE1hbYzTsiZmKjJvJcNqyR_l457uHr2TGUBltdLsSpoOYiZziuuPXQ1tzSDXP9PKVjsstYeTc',
#      'width': 4000}],
#    'place_id': 'ChIJ9RNxcQNy5kcRnZJ4vsuXcow',
#    'plus_code': {'compound_code': 'R9XC+58 Paris, France',
#     'global_code': '8FW4R9XC+58'},
#    'rating': 4,
#    'reference': 'ChIJ9RNxcQNy5kcRnZJ4vsuXcow',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 784,
#    'vicinity': '41/43 Avenue Ledru Rollin, Paris'},
#   {'business_status': 'CLOSED_TEMPORARILY',
#    'geometry': {'location': {'lat': 48.8710647, 'lng': 2.34991},
#     'viewport': {'northeast': {'lat': 48.87241888029151,
#       'lng': 2.351188530291502},
#      'southwest': {'lat': 48.86972091970851, 'lng': 2.348490569708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Hôtel des Comédies Paris',
#    'permanently_closed': True,
#    'photos': [{'height': 683,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108479076312462330074">Hotels World Online</a>'],
#      'photo_reference': 'Aap_uEDK0EeX72TZVp8Ne7reU4FImH2sFVF4peZXJKuYBS9V-8K389UfIjoZcQ40Kghu_6NzgvvUoRhlWQXwh-jel1kn1CzB-gywv9PqBUTEdOq0BN2_5ZlNNcJBsMVrw2LZh3Ijq5QBty8-4Hb74hvh7VkWlYfdxtXh8E3lw9vuffJ567n6',
#      'width': 1024}],
#    'place_id': 'ChIJn6ginxZu5kcRmAEK0OHm0cI',
#    'plus_code': {'compound_code': 'V8CX+CX Paris, France',
#     'global_code': '8FW4V8CX+CX'},
#    'rating': 4.2,
#    'reference': 'ChIJn6ginxZu5kcRmAEK0OHm0cI',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 194,
#    'vicinity': "8 Rue d'Hauteville, Paris"},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.84754640000001, 'lng': 2.3718722},
#     'viewport': {'northeast': {'lat': 48.8488750302915,
#       'lng': 2.373125480291502},
#      'southwest': {'lat': 48.8461770697085, 'lng': 2.370427519708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Hôtel De France Gare de Lyon Bastille',
#    'photos': [{'height': 787,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117462031751048846575">Hôtel De France Gare de Lyon Bastille</a>'],
#      'photo_reference': 'Aap_uEBFZVw01prh_7NryOxsIOssGkRIv3KDwunYsiCLiuwO2vBp9zvt6FCB-MQqBRDz_SWV9kCHbIcgN90zaAfssI_OnivGFl1xwp1nBih7pVmZyusa2PmwgofsOv7wAQVa1q4cgRbbPAza_T8Ftsss5DjGFdSN76UwcOP8Yh0v9zDO_n5q',
#      'width': 1181}],
#    'place_id': 'ChIJz6DBYgNy5kcRhOu1LhDIECM',
#    'plus_code': {'compound_code': 'R9XC+2P Paris, France',
#     'global_code': '8FW4R9XC+2P'},
#    'rating': 3.3,
#    'reference': 'ChIJz6DBYgNy5kcRhOu1LhDIECM',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 380,
#    'vicinity': '12 Rue de Lyon, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8717386, 'lng': 2.3447052},
#     'viewport': {'northeast': {'lat': 48.8731394302915,
#       'lng': 2.346067130291502},
#      'southwest': {'lat': 48.8704414697085, 'lng': 2.343369169708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Hôtel Prélude Opéra Paris',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2448,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106224131803115407650">Marcin Marczak</a>'],
#      'photo_reference': 'Aap_uEDO8F1ADsrpbHuHLDNSdbu8aFX1gyAu5-HrSwvEw8UNIxzQWdnw3wsBYKGCGOnfZ0BjkmNuaWAAlzZsCWgJYQPND9uKJk2v0gphTLhFry5RZ3HSZ5me-doR6stuexA-qcF-KTd9bcSWtgr2CxVTL-o2_yCKvZ6-WNxbPiQ748iTDto6',
#      'width': 3264}],
#    'place_id': 'ChIJ8e3Qcj5u5kcR2MIGwNxustk',
#    'plus_code': {'compound_code': 'V8CV+MV Paris, France',
#     'global_code': '8FW4V8CV+MV'},
#    'rating': 4.1,
#    'reference': 'ChIJ8e3Qcj5u5kcR2MIGwNxustk',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 355,
#    'vicinity': '8 Cité Bergère, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8423491, 'lng': 2.3632246},
#     'viewport': {'northeast': {'lat': 48.84365908029149,
#       'lng': 2.364711430291502},
#      'southwest': {'lat': 48.8409611197085, 'lng': 2.362013469708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Hôtel Libertel Austerlitz Jardin des Plantes',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4480,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114802271282641766772">Hôtel Libertel Austerlitz Jardin des Plantes</a>'],
#      'photo_reference': 'Aap_uEA_oaky5aub2AtfziI7Umva5seA-hLidCfiwQj62w3fOE5z12Zwp3ZRi4YQDhont6EgSUrzLY5ZVkDtTMn_7YrID39lPpwWcsgHUAk8rribSoCvRPgc1nzExrJTP3S-mrOxfce9pyLvzTm6epG0zD0yy--qBhOfdXFHv64OwqPgUFlv',
#      'width': 6720}],
#    'place_id': 'ChIJe-udXPZx5kcRKURHNFv5BSw',
#    'plus_code': {'compound_code': 'R9R7+W7 Paris, France',
#     'global_code': '8FW4R9R7+W7'},
#    'rating': 4,
#    'reference': 'ChIJe-udXPZx5kcRKURHNFv5BSw',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 433,
#    'vicinity': "12 Boulevard de l'Hôpital, Paris"},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.864294, 'lng': 2.3307997},
#     'viewport': {'northeast': {'lat': 48.8655772302915,
#       'lng': 2.332153880291502},
#      'southwest': {'lat': 48.8628792697085, 'lng': 2.329455919708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Saint James Albany Paris Hôtel Spa',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 400,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108570400659068256718">Saint James Albany Paris Hôtel Spa</a>'],
#      'photo_reference': 'Aap_uEB6Z0TF1YRaJv8ucnjf7uP3Hou7IDV7NEQyNWob1qvm-H54Xanl-5RPmy1OzyuM21LcUj5WnDId5BlrmMXMTR-EQsUlv7M03ksuZjaZ9Ok8joIbW4BSWE2_bL_ldoNYfGCbdBImOEdV4Crhl2hv-TOCZrPBIh42bPPNthL6i2HbqTLQ',
#      'width': 600}],
#    'place_id': 'ChIJ8znTVS5u5kcREq8TmzOICFs',
#    'plus_code': {'compound_code': 'V87J+P8 Paris, France',
#     'global_code': '8FW4V87J+P8'},
#    'rating': 4,
#    'reference': 'ChIJ8znTVS5u5kcREq8TmzOICFs',
#    'scope': 'GOOGLE',
#    'types': ['lodging',
#     'bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 1074,
#    'vicinity': '202 Rue de Rivoli, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.87110329999999, 'lng': 2.3389728},
#     'viewport': {'northeast': {'lat': 48.8724588802915,
#       'lng': 2.340112930291502},
#      'southwest': {'lat': 48.8697609197085, 'lng': 2.337414969708499}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Hôtel Icône',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1066,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108137830440312077288">Hôtel Icône</a>'],
#      'photo_reference': 'Aap_uECKV1Ssa7l_D0G-trYoRAcjcnjY2hxBoZXv8fx0nAzbL-PhbYVIZZ6BCYSG5yqol-CACQJimZpuk95hjW0e1uUeHc9OIQ9K3_f6BqlhAEWvH6p0x4-c14i5oPj6B2A5MdS6Ipkl2lPmhgYw4dKaTzpL7Hzj3sog2GpVIvggFvt4Ta8C',
#      'width': 1600}],
#    'place_id': 'ChIJpQvq5Dtu5kcR0COam2f7v_I',
#    'plus_code': {'compound_code': 'V8CQ+CH Paris, France',
#     'global_code': '8FW4V8CQ+CH'},
#    'rating': 3.8,
#    'reference': 'ChIJpQvq5Dtu5kcR0COam2f7v_I',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 138,
#    'vicinity': "4 Rue d'Amboise, Paris"},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8524547, 'lng': 2.3472064},
#     'viewport': {'northeast': {'lat': 48.8538838802915,
#       'lng': 2.348601530291502},
#      'southwest': {'lat': 48.8511859197085, 'lng': 2.345903569708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Hôtel Esmeralda',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 1960,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106443224837840180239">Fraz A. Khan</a>'],
#      'photo_reference': 'Aap_uEAg5oagJjTR2AFW6l0nFNIJVR_Tutyd9h53boFSEXh4lmiTLq6FBWBQ5UC2Nie-1YBs5mCLMBxchJK0b3VdaM30_n6zlQCTJ7yvwmlszKaFx2zqXcus439QejtnUfBu0Qvryf8TyZYNWXMD9OEYAINsZpTjmgQ7Yh_HFlx8uxLHBXVF',
#      'width': 4032}],
#    'place_id': 'ChIJO_g_H-Fx5kcRmaabUHA3dT4',
#    'plus_code': {'compound_code': 'V82W+XV Paris, France',
#     'global_code': '8FW4V82W+XV'},
#    'rating': 4.1,
#    'reference': 'ChIJO_g_H-Fx5kcRmaabUHA3dT4',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 143,
#    'vicinity': '4 Rue Saint-Julien le Pauvre, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8530901, 'lng': 2.3447174},
#     'viewport': {'northeast': {'lat': 48.8544403302915,
#       'lng': 2.346001280291502},
#      'southwest': {'lat': 48.8517423697085, 'lng': 2.343303319708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Albe Hotel',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1152,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117571951379278191466">Albe Hotel Saint Michel</a>'],
#      'photo_reference': 'Aap_uEDpIFHgFPxQLCxy6YL7nuyK-KiydAJItk_d4xb8ttLbjJ7D4lZer5seIpVOQZLnpBUXjpmpEEXNQmcdq0lf2WkyaRHN4DU8hhzTQ9cmvPq4dNZ6JH9gDvWI0DP41XwFpqhq2CrWWvM1F3SJ8a-674EnByUNSTWiouqQc4gxj3lkCzEm',
#      'width': 1600}],
#    'place_id': 'ChIJ8R5-hOBx5kcRsCOdfj8GLeY',
#    'plus_code': {'compound_code': 'V83V+6V Paris, France',
#     'global_code': '8FW4V83V+6V'},
#    'rating': 4.4,
#    'reference': 'ChIJ8R5-hOBx5kcRsCOdfj8GLeY',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 325,
#    'vicinity': '1 Rue de la Harpe, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8499394, 'lng': 2.3462397},
#     'viewport': {'northeast': {'lat': 48.8512682802915,
#       'lng': 2.347501880291502},
#      'southwest': {'lat': 48.8485703197085, 'lng': 2.344803919708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Home Latin',
#    'photos': [{'height': 606,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105830788751825835396">Peter Sheehan</a>'],
#      'photo_reference': 'Aap_uEDu0ow53BbX5KZo9YWaoiNuj7xZEwDrgBF_glnlcEeBuGTRFC_H4JNb0CGLqs7cW9g1aVuOgl1ZjmgBqlByTgrhxmNM_C-UNRg7lQw05bXCr0xsS76rx5hSjRJKgbe7BdTIjtYlehQUP7qIC56zYqwTBG1Be4WfuURpVunu5bmcc7-M',
#      'width': 1080}],
#    'place_id': 'ChIJMWNDIudx5kcRupjNdNDYKkw',
#    'plus_code': {'compound_code': 'R8XW+XF Paris, France',
#     'global_code': '8FW4R8XW+XF'},
#    'rating': 3.6,
#    'reference': 'ChIJMWNDIudx5kcRupjNdNDYKkw',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 265,
#    'vicinity': '15-17 Rue du Sommerard, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.85473870000001, 'lng': 2.3395455},
#     'viewport': {'northeast': {'lat': 48.8561127802915,
#       'lng': 2.340820530291502},
#      'southwest': {'lat': 48.8534148197085, 'lng': 2.338122569708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': "Hôtel d'Aubusson",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2174,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115702439863948549296">Hôtel d&#39;Aubusson Paris</a>'],
#      'photo_reference': 'Aap_uECzdZIYY12ZhBmYLvFw8JGwkCG_pzI8OCsioHHvUf9yIH3T3jmzwNgmYHsz7fGKi3Eo4ZR0ktR7gJ2fZX7HabGDiO0R_nyDgtrwFzOLE38hWN2yPDVQm1bToNz38lhinJJcCsit0MXeNypGGHYtUZ9jAQytT_KcfW2iD9A0GWbIojn5',
#      'width': 1739}],
#    'place_id': 'ChIJk6ztMN9x5kcREpQ8edWOs7E',
#    'plus_code': {'compound_code': 'V83Q+VR Paris, France',
#     'global_code': '8FW4V83Q+VR'},
#    'rating': 4.7,
#    'reference': 'ChIJk6ztMN9x5kcREpQ8edWOs7E',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 278,
#    'vicinity': '33 Rue Dauphine, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.85184049999999, 'lng': 2.3448082},
#     'viewport': {'northeast': {'lat': 48.85313113029149,
#       'lng': 2.346144730291502},
#      'southwest': {'lat': 48.8504331697085, 'lng': 2.343446769708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Hôtel 4 étoiles Parc Saint Séverin Paris 5ème - Esprit de France',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2362,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107542132357877294567">Hôtel 4 étoiles Parc Saint Séverin Paris 5ème - Esprit de France</a>'],
#      'photo_reference': 'Aap_uEAsaGL0Gi4BC7WhMqVKPcBcPp5Xuf314wf4MIGdyK6EA7kFya-H3088PKM2QP1gNgRVtMJEjCG8HRASN1E-pJjlV2VQwVlRRre-tpdeU4YkhVgcosTyZxIEhUJ1Dj21vH69QvckHXtg_IYzwTYJICaF9OcfhWey0tsd60p4byqC-O_o',
#      'width': 3776}],
#    'place_id': 'ChIJ9--kuuBx5kcRojwQ1yEK2cY',
#    'plus_code': {'compound_code': 'V82V+PW Paris, France',
#     'global_code': '8FW4V82V+PW'},
#    'rating': 4.6,
#    'reference': 'ChIJ9--kuuBx5kcRojwQ1yEK2cY',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 139,
#    'vicinity': '22 Rue de la Parcheminerie, Paris'}],
#  'status': 'OK'}

# %%
# 6b. Iterate through the hotel DataFrame.
for index, row in hotel_df.iterrows():

    # 6c. Get latitude and longitude from DataFrame
    lat = row["Lat"]
    lng = row["Lng"]

    # 6d. Set up the base URL for the Google Directions API to get JSON data.
    params["location"] = f"{lat},{lng}"

    # 6d. Set up the base URL for the Google Directions API to get JSON data.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
   
    # 6e. Make request and retrieve the JSON data from the search. 
    hotels = requests.get(base_url, params=params).json()
    
    # 6f. Get the first hotel from the results and store the name, if a hotel isn't found skip the city.
    print()
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found... skipping.")
# Out:
# Hotel not found... skipping.
#
# Hotel not found... skipping.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Hotel not found... skipping.
#
# Hotel not found... skipping.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Hotel not found... skipping.
#
#
# Hotel not found... skipping.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Hotel not found... skipping.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Hotel not found... skipping.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Hotel not found... skipping.
#
#
#
#
#
#
#
# Hotel not found... skipping.
#
#
#
#
#
#
#
#
#
#
#
#
#
# Hotel not found... skipping.
#
#
#
#
#
#
# Hotel not found... skipping.
#
#
#
#
#
#
# Hotel not found... skipping.
#
#
#
#
#
#
#
#
#
#
#
#
# Hotel not found... skipping.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Hotel not found... skipping.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Hotel not found... skipping.
#
#
#
# Hotel not found... skipping.
#
#
#
#
#
#
#
#
#
#
# Hotel not found... skipping.
#
# Hotel not found... skipping.

# %%
# 7. Drop the rows where there is no Hotel Name.
clean_hotel_df = hotel_df[hotel_df['Hotel Name'] != ""]
clean_hotel_df
# Out:
#                  City Country  Max Temp Current Description      Lat  \
# 1             Samarai      PG     79.95     overcast clouds -10.6167
# 4           Kavaratti      IN     81.99     overcast clouds  10.5669
# 6       Traverse City      US     75.94           clear sky  44.7631
# 7             Wahiawa      US     88.12          light rain  21.5028
# 11               Hilo      US     80.33          light rain  19.7297
# 14             Vanino      RU     82.90     overcast clouds  49.0869
# 24            Limbang      MY     82.71       broken clouds   4.7500
# 29               Lamu      KE     77.22       broken clouds  -2.2717
# 30        Dicabisagan      PH     87.57     overcast clouds  17.0818
# 44            Isangel      VU     86.11       broken clouds -19.5500
# 55           Westport      US     76.19           clear sky  41.1415
# 56             Taybad      IR     79.90           clear sky  34.7400
# 58         Butaritari      KI     83.77          light rain   3.0707
# 63             Iwanai      JP     85.93    scattered clouds  42.9744
# 64       Saint George      US     85.53          few clouds  37.1041
# 70              Fukue      JP     79.16       broken clouds  32.6881
# 72              Vaini      TO     78.96          few clouds -21.2000
# 74            Bourail      NC     81.00           clear sky -21.5667
# 80             Avarua      CK     78.85       broken clouds -21.2078
# 81          Bathsheba      BB     79.41          few clouds  13.2167
# 83     Puerto Cabello      VE     80.91     overcast clouds  10.4731
# 85             Atuona      PF     78.40          few clouds  -9.8000
# 88              Kapaa      US     84.18          light rain  22.0752
# 91               Auki      SB     82.56       broken clouds  -8.7676
# 93            Aquiraz      BR     81.21           clear sky  -3.9014
# 94            Honiara      SB     85.46    scattered clouds  -9.4333
# 95               Tura      IN     76.82     overcast clouds  25.5198
# 99            Kushima      JP     86.04     overcast clouds  31.4583
# 102            Maceio      BR     76.44       broken clouds  -9.6658
# 103            Nabire      ID     77.45     overcast clouds  -3.3667
# ..                ...     ...       ...                 ...      ...
# 622              Gizo      SB     83.01          light rain  -8.1030
# 624       Qinhuangdao      CN     81.99          light rain  39.9317
# 627           Salalah      OM     77.09             drizzle  17.0151
# 632           Russell      US     87.40       broken clouds  32.3502
# 635            Neiafu      TO     84.88          light rain -18.6500
# 637             Praia      CV     75.74       broken clouds  14.9215
# 639        Porto Novo      BJ     78.62          few clouds   6.4965
# 641          Marietta      US     85.78       broken clouds  33.9526
# 643            Tomari      RU     77.74     overcast clouds  47.7658
# 645           Kyaukse      MM     80.60       broken clouds  21.6000
# 646           Laramie      US     78.73           clear sky  41.3114
# 650          Fairhope      US     85.75           clear sky  30.5230
# 651             Hojai      IN     81.34     overcast clouds  26.0000
# 652             Ateli      IN     85.19           clear sky  28.1000
# 659          Belmopan      BZ     86.38     overcast clouds  17.2500
# 660        Prabumulih      ID     78.26           clear sky  -3.4500
# 665         Magdalena      PH     80.40     overcast clouds  14.1999
# 674              Biak      ID     79.48       broken clouds  -0.9131
# 682      Isla Mujeres      MX     84.16     overcast clouds  21.2311
# 684     Bambanglipuro      ID     79.25    scattered clouds  -7.9500
# 687      Baloda Bazar      IN     76.66     overcast clouds  21.6667
# 688         Pontianak      ID     80.58          few clouds  -0.0333
# 691     San Cristobal      VE     75.38     overcast clouds   7.7669
# 696            Lipari      IT     78.94           clear sky  38.4674
# 697             Mecca      SA     86.36       broken clouds  21.4267
# 702             Mahon      ES     77.56           clear sky  39.8885
# 704             Alofi      NU     82.29          few clouds -19.0595
# 706  San Jose De Ocoa      DO     76.68     overcast clouds  18.5500
# 708            Dryden      CA     77.29       broken clouds  49.7833
# 709     Sioux Lookout      CA     77.38               smoke  50.1001
#
#           Lng                                         Hotel Name
# 1    150.6667                                          Nuli Sapi
# 4     72.6420                      Hotels in Lakshadweep Islands
# 6    -85.6206                                    Bayshore Resort
# 7   -158.0236                                      Aloha Wahiawa
# 11  -155.0900                                Hilo Hawaiian Hotel
# 14   140.2543                                  Гостиница 5 Звезд
# 24   115.0000                                      Purnama Hotel
# 29    40.9020                                         Lamu House
# 30   122.4157                            Nancy Montanes Bernardo
# 44   169.2667                                        Tanna Lodge
# 55   -73.3579                                   The Westport Inn
# 56    60.7756                                 لی پوش jean center
# 58   172.7902                                 Isles Sunset Lodge
# 63   140.5089                                          いわない高原ホテル
# 64  -113.5841                        Best Western Plus Abbey Inn
# 70   128.8419            Goto Guesthouse Utojuku & SA Car Rental
# 72  -175.2000                                Keleti Beach Resort
# 74   165.4833                                    Motel Allamanda
# 80  -159.7750                                       Paradise Inn
# 81   -59.5167                                     Atlantis Hotel
# 83   -68.0125                                      Hotel Cumboto
# 85  -139.0333                                        Villa Enata
# 88  -159.3190                Sheraton Kauai Coconut Beach Resort
# 91   160.7034                                         Auki Motel
# 93   -38.3911                              Pousada Rua Camurupim
# 94   159.9500                                Heritage Park Hotel
# 95    90.2201                           Hotel RIKMAN Continental
# 99   131.2333                                            Hanaoka
# 102  -35.7353                                     Poutur Pousada
# 103  135.4833                             Hotel Nusantara Nabire
# ..        ...                                                ...
# 622  156.8419                                 Imagination Island
# 624  119.5883  Qinhuangdao Peninsula Seasons Hotel And Apartment
# 627   54.0924                         HAMDAN PLAZA HOTEL SALALAH
# 632  -85.1999                                               Macs
# 635 -173.9833              Mystic Sands Beachfront Accommodation
# 637  -23.5087                                      LT Aparthotel
# 639    2.6036                            Tour Eiffel Hotel Benin
# 641  -84.5499  Hilton Atlanta/Marietta Hotel & Conference Center
# 643  142.0683                                        Vostochnaya
# 645   96.1333                           Shwe Thit Sar Guesthouse
# 646 -105.5911         Fairfield Inn & Suites by Marriott Laramie
# 650  -87.9033                    Hampton Inn Fairhope-Mobile Bay
# 651   92.8667                                  Luxury park hotel
# 652   76.2833                                    Priyanshu house
# 659  -88.7667                                     Villa San Juan
# 660  104.2500                OYO 2722 Lemon Residence Prabumulih
# 665  121.4290                    Samparada & Gestiada Residences
# 674  122.8766                                     Penginapan Kim
# 682  -86.7310                         Hotel La Joya Isla Mujeres
# 684  110.2833                                         Puri Brata
# 687   82.1667                          STARiHOTELS Baloda Bazaar
# 688  109.3333          Aston Pontianak Hotel & Convention Center
# 691  -72.2250                               Posada Villaven C.A.
# 696   14.9540      Hotel Villa Diana Soc. Clelia Hunziker s.a.s.
# 697   39.8261         Makkah Clock Royal Tower, A Fairmont Hotel
# 702    4.2658                                       ARTIEM Capri
# 704 -169.9187                                      Taloa Heights
# 706  -70.5000                                    Hotel El Barcon
# 708  -92.7503           Holiday Inn Express Dryden, an IHG Hotel
# 709  -91.9170                              Knobby's Fly-In Camps
#
# [236 rows x 7 columns]

# %%
# 8a. Create the output File (CSV)
output_data_file = 'WeatherPy_vacation.csv'

# 8b. Export the City_Data into a csv
clean_hotel_df.to_csv(output_data_file, index_label="City_ID")

# %%
# 9. Using the template add city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 10a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in clean_hotel_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = clean_hotel_df[["Lat", "Lng"]]

# %%
gmaps.configure(api_key=gkey)

# %%
# 11a. Add a marker layer for each city to the map.
max_temp = clean_hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,
             dissipating=False, max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
