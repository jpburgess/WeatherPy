# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from citipy import citipy

import requests
from config import weather_api_key

from datetime import datetime

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
len(coordinates)
# Out:
# 2000

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 772

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)

# %%
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url).json()
city_weather
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 69.8,
#   'feels_like': 69.67,
#   'temp_min': 65.95,
#   'temp_max': 72.82,
#   'pressure': 1017,
#   'humidity': 68},
#  'visibility': 10000,
#  'wind': {'speed': 1.01, 'deg': 224, 'gust': 1.99},
#  'clouds': {'all': 100},
#  'dt': 1627173288,
#  'sys': {'type': 2,
#   'id': 2001997,
#   'country': 'US',
#   'sunrise': 1627118936,
#   'sunset': 1627171934},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
city_description = city_weather["weather"][0]['description']
city_description
# Out:
# 'overcast clouds'

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description" : city_description
                          })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ribeira grande
# Processing Record 2 of Set 1 | samarai
# Processing Record 3 of Set 1 | novoagansk
# Processing Record 4 of Set 1 | caravelas
# Processing Record 5 of Set 1 | kavaratti
# Processing Record 6 of Set 1 | aklavik
# Processing Record 7 of Set 1 | traverse city
# Processing Record 8 of Set 1 | wahiawa
# Processing Record 9 of Set 1 | cerchezu
# Processing Record 10 of Set 1 | jamestown
# Processing Record 11 of Set 1 | mahebourg
# Processing Record 12 of Set 1 | hilo
# Processing Record 13 of Set 1 | castro
# Processing Record 14 of Set 1 | rikitea
# Processing Record 15 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 16 of Set 1 | vanino
# Processing Record 17 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 18 of Set 1 | anchorage
# Processing Record 19 of Set 1 | ushuaia
# Processing Record 20 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 21 of Set 1 | verkhnevilyuysk
# Processing Record 22 of Set 1 | thinadhoo
# Processing Record 23 of Set 1 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 24 of Set 1 | punta arenas
# Processing Record 25 of Set 1 | khatanga
# Processing Record 26 of Set 1 | barrow
# Processing Record 27 of Set 1 | tadine
# Processing Record 28 of Set 1 | broken hill
# Processing Record 29 of Set 1 | limbang
# Processing Record 30 of Set 1 | nikolskoye
# Processing Record 31 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 32 of Set 1 | busselton
# Processing Record 33 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 34 of Set 1 | bethel
# Processing Record 35 of Set 1 | sobolevo
# Processing Record 36 of Set 1 | lamu
# Processing Record 37 of Set 1 | dicabisagan
# Processing Record 38 of Set 1 | yellowknife
# Processing Record 39 of Set 1 | ngara
# Processing Record 40 of Set 1 | port moresby
# Processing Record 41 of Set 1 | pisco
# Processing Record 42 of Set 1 | lebu
# Processing Record 43 of Set 1 | chokurdakh
# Processing Record 44 of Set 1 | eldikan
# City not found. Skipping...
# Processing Record 45 of Set 1 | talnakh
# Processing Record 46 of Set 1 | atar
# Processing Record 47 of Set 1 | pokrovsk
# Processing Record 48 of Set 1 | port alfred
# Processing Record 49 of Set 1 | havre-saint-pierre
# Processing Record 50 of Set 1 | port-cartier
# Processing Record 1 of Set 2 | camoapa
# Processing Record 2 of Set 2 | isangel
# Processing Record 3 of Set 2 | tumbes
# Processing Record 4 of Set 2 | dikson
# Processing Record 5 of Set 2 | lasa
# Processing Record 6 of Set 2 | saint-philippe
# Processing Record 7 of Set 2 | east london
# Processing Record 8 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 9 of Set 2 | genhe
# Processing Record 10 of Set 2 | kayseri
# Processing Record 11 of Set 2 | jomalig
# City not found. Skipping...
# Processing Record 12 of Set 2 | mataura
# Processing Record 13 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 14 of Set 2 | amga
# Processing Record 15 of Set 2 | qaanaaq
# Processing Record 16 of Set 2 | westport
# Processing Record 17 of Set 2 | taybad
# Processing Record 18 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 19 of Set 2 | bangassou
# Processing Record 20 of Set 2 | butaritari
# Processing Record 21 of Set 2 | aguas belas
# Processing Record 22 of Set 2 | yermolayevo
# Processing Record 23 of Set 2 | bukachacha
# Processing Record 24 of Set 2 | kruisfontein
# Processing Record 25 of Set 2 | iwanai
# Processing Record 26 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 27 of Set 2 | saint george
# Processing Record 28 of Set 2 | albany
# Processing Record 29 of Set 2 | cabo san lucas
# Processing Record 30 of Set 2 | trofors
# Processing Record 31 of Set 2 | mehamn
# Processing Record 32 of Set 2 | cape town
# Processing Record 33 of Set 2 | fukue
# Processing Record 34 of Set 2 | susehri
# Processing Record 35 of Set 2 | vaini
# Processing Record 36 of Set 2 | bluff
# Processing Record 37 of Set 2 | bourail
# Processing Record 38 of Set 2 | sao felix do xingu
# Processing Record 39 of Set 2 | thompson
# Processing Record 40 of Set 2 | slave lake
# Processing Record 41 of Set 2 | provideniya
# Processing Record 42 of Set 2 | carnarvon
# Processing Record 43 of Set 2 | avarua
# Processing Record 44 of Set 2 | bathsheba
# Processing Record 45 of Set 2 | margate
# Processing Record 46 of Set 2 | puerto cabello
# Processing Record 47 of Set 2 | ilulissat
# Processing Record 48 of Set 2 | atuona
# Processing Record 49 of Set 2 | codrington
# Processing Record 50 of Set 2 | saskylakh
# Processing Record 1 of Set 3 | kapaa
# Processing Record 2 of Set 3 | bredasdorp
# Processing Record 3 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 4 of Set 3 | mortka
# Processing Record 5 of Set 3 | auki
# Processing Record 6 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 7 of Set 3 | mapiripan
# Processing Record 8 of Set 3 | aquiraz
# Processing Record 9 of Set 3 | honiara
# Processing Record 10 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 11 of Set 3 | tura
# Processing Record 12 of Set 3 | arlit
# Processing Record 13 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 14 of Set 3 | sitka
# Processing Record 15 of Set 3 | cherskiy
# Processing Record 16 of Set 3 | kushima
# Processing Record 17 of Set 3 | lavrentiya
# Processing Record 18 of Set 3 | xining
# Processing Record 19 of Set 3 | maceio
# Processing Record 20 of Set 3 | nabire
# Processing Record 21 of Set 3 | avera
# Processing Record 22 of Set 3 | belmonte
# Processing Record 23 of Set 3 | jamame
# Processing Record 24 of Set 3 | amalapuram
# Processing Record 25 of Set 3 | tuktoyaktuk
# Processing Record 26 of Set 3 | sao filipe
# Processing Record 27 of Set 3 | pacifica
# Processing Record 28 of Set 3 | iquitos
# Processing Record 29 of Set 3 | lhuntshi
# City not found. Skipping...
# Processing Record 30 of Set 3 | chore
# City not found. Skipping...
# Processing Record 31 of Set 3 | hermanus
# Processing Record 32 of Set 3 | terrak
# Processing Record 33 of Set 3 | luderitz
# Processing Record 34 of Set 3 | puerto ayora
# Processing Record 35 of Set 3 | vestmannaeyjar
# Processing Record 36 of Set 3 | yulara
# Processing Record 37 of Set 3 | norman wells
# Processing Record 38 of Set 3 | georgetown
# Processing Record 39 of Set 3 | coihaique
# Processing Record 40 of Set 3 | terra santa
# Processing Record 41 of Set 3 | hokitika
# Processing Record 42 of Set 3 | hithadhoo
# Processing Record 43 of Set 3 | nador
# Processing Record 44 of Set 3 | trelew
# Processing Record 45 of Set 3 | estelle
# Processing Record 46 of Set 3 | kodiak
# Processing Record 47 of Set 3 | harper
# Processing Record 48 of Set 3 | la plata
# Processing Record 49 of Set 3 | srednekolymsk
# Processing Record 50 of Set 3 | birin
# Processing Record 1 of Set 4 | richards bay
# Processing Record 2 of Set 4 | yenagoa
# Processing Record 3 of Set 4 | upernavik
# Processing Record 4 of Set 4 | sooke
# Processing Record 5 of Set 4 | boda
# Processing Record 6 of Set 4 | belogorsk
# Processing Record 7 of Set 4 | tiksi
# Processing Record 8 of Set 4 | te anau
# Processing Record 9 of Set 4 | hornepayne
# Processing Record 10 of Set 4 | kjopsvik
# Processing Record 11 of Set 4 | tasiilaq
# Processing Record 12 of Set 4 | cidreira
# Processing Record 13 of Set 4 | hobart
# Processing Record 14 of Set 4 | zheleznodorozhnyy
# Processing Record 15 of Set 4 | lazaro cardenas
# Processing Record 16 of Set 4 | weinan
# Processing Record 17 of Set 4 | new norfolk
# Processing Record 18 of Set 4 | ixtapa
# Processing Record 19 of Set 4 | robertsport
# Processing Record 20 of Set 4 | george
# Processing Record 21 of Set 4 | canico
# Processing Record 22 of Set 4 | epe
# Processing Record 23 of Set 4 | hibbing
# Processing Record 24 of Set 4 | homer
# Processing Record 25 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 26 of Set 4 | erzincan
# Processing Record 27 of Set 4 | baykit
# Processing Record 28 of Set 4 | tirat karmel
# Processing Record 29 of Set 4 | kodinsk
# Processing Record 30 of Set 4 | tansen
# Processing Record 31 of Set 4 | longyearbyen
# Processing Record 32 of Set 4 | sabang
# Processing Record 33 of Set 4 | ondjiva
# Processing Record 34 of Set 4 | el dovio
# Processing Record 35 of Set 4 | manihari
# Processing Record 36 of Set 4 | tete
# Processing Record 37 of Set 4 | svetlogorsk
# Processing Record 38 of Set 4 | vernon
# Processing Record 39 of Set 4 | nakonde
# Processing Record 40 of Set 4 | kahului
# Processing Record 41 of Set 4 | bandarbeyla
# Processing Record 42 of Set 4 | wajima
# Processing Record 43 of Set 4 | port hardy
# Processing Record 44 of Set 4 | whitehorse
# Processing Record 45 of Set 4 | mopipi
# Processing Record 46 of Set 4 | rawson
# Processing Record 47 of Set 4 | haines junction
# Processing Record 48 of Set 4 | oranjemund
# Processing Record 49 of Set 4 | port lincoln
# Processing Record 50 of Set 4 | severo-kurilsk
# Processing Record 1 of Set 5 | itarema
# Processing Record 2 of Set 5 | zalesovo
# Processing Record 3 of Set 5 | aksarka
# Processing Record 4 of Set 5 | aketi
# Processing Record 5 of Set 5 | solovetskiy
# City not found. Skipping...
# Processing Record 6 of Set 5 | alice springs
# Processing Record 7 of Set 5 | amahai
# Processing Record 8 of Set 5 | bundaberg
# Processing Record 9 of Set 5 | muisne
# Processing Record 10 of Set 5 | dakoro
# Processing Record 11 of Set 5 | millau
# Processing Record 12 of Set 5 | kaitangata
# Processing Record 13 of Set 5 | oranjestad
# Processing Record 14 of Set 5 | barda
# Processing Record 15 of Set 5 | hasaki
# Processing Record 16 of Set 5 | mar del plata
# Processing Record 17 of Set 5 | yamada
# Processing Record 18 of Set 5 | xichang
# Processing Record 19 of Set 5 | oksfjord
# Processing Record 20 of Set 5 | klyuchi
# Processing Record 21 of Set 5 | suleja
# Processing Record 22 of Set 5 | irbeyskoye
# Processing Record 23 of Set 5 | stanger
# Processing Record 24 of Set 5 | jumla
# Processing Record 25 of Set 5 | mentok
# City not found. Skipping...
# Processing Record 26 of Set 5 | jalingo
# Processing Record 27 of Set 5 | deputatskiy
# Processing Record 28 of Set 5 | fairview
# Processing Record 29 of Set 5 | upata
# Processing Record 30 of Set 5 | port blair
# Processing Record 31 of Set 5 | iqaluit
# Processing Record 32 of Set 5 | vostok
# Processing Record 33 of Set 5 | port elizabeth
# Processing Record 34 of Set 5 | kinsale
# Processing Record 35 of Set 5 | broadstairs
# Processing Record 36 of Set 5 | grindavik
# Processing Record 37 of Set 5 | sorland
# Processing Record 38 of Set 5 | ahipara
# Processing Record 39 of Set 5 | namibe
# Processing Record 40 of Set 5 | comodoro rivadavia
# Processing Record 41 of Set 5 | olafsvik
# Processing Record 42 of Set 5 | da nang
# Processing Record 43 of Set 5 | rondonopolis
# Processing Record 44 of Set 5 | lerwick
# Processing Record 45 of Set 5 | camargo
# Processing Record 46 of Set 5 | arraial do cabo
# Processing Record 47 of Set 5 | airai
# Processing Record 48 of Set 5 | diamantina
# Processing Record 49 of Set 5 | antalaha
# Processing Record 50 of Set 5 | juneau
# Processing Record 1 of Set 6 | takoradi
# Processing Record 2 of Set 6 | inuvik
# Processing Record 3 of Set 6 | los llanos de aridane
# Processing Record 4 of Set 6 | sirjan
# Processing Record 5 of Set 6 | providencia
# Processing Record 6 of Set 6 | urumqi
# Processing Record 7 of Set 6 | atarra
# Processing Record 8 of Set 6 | cornelius
# Processing Record 9 of Set 6 | poum
# Processing Record 10 of Set 6 | faanui
# Processing Record 11 of Set 6 | ostrovnoy
# Processing Record 12 of Set 6 | ariquemes
# Processing Record 13 of Set 6 | tshikapa
# Processing Record 14 of Set 6 | nan
# Processing Record 15 of Set 6 | dunedin
# Processing Record 16 of Set 6 | grimari
# City not found. Skipping...
# Processing Record 17 of Set 6 | torbay
# Processing Record 18 of Set 6 | suba
# Processing Record 19 of Set 6 | victoria
# Processing Record 20 of Set 6 | hambantota
# Processing Record 21 of Set 6 | oistins
# Processing Record 22 of Set 6 | prince rupert
# Processing Record 23 of Set 6 | geraldton
# Processing Record 24 of Set 6 | duldurga
# Processing Record 25 of Set 6 | beruwala
# Processing Record 26 of Set 6 | riviere-au-renard
# Processing Record 27 of Set 6 | miles city
# Processing Record 28 of Set 6 | yeppoon
# Processing Record 29 of Set 6 | clyde river
# Processing Record 30 of Set 6 | esperance
# Processing Record 31 of Set 6 | huanuco
# Processing Record 32 of Set 6 | bilibino
# Processing Record 33 of Set 6 | karkaralinsk
# City not found. Skipping...
# Processing Record 34 of Set 6 | kaka
# Processing Record 35 of Set 6 | xai-xai
# Processing Record 36 of Set 6 | lima
# Processing Record 37 of Set 6 | hobyo
# Processing Record 38 of Set 6 | luanda
# Processing Record 39 of Set 6 | bandipur
# Processing Record 40 of Set 6 | elat
# Processing Record 41 of Set 6 | padang
# Processing Record 42 of Set 6 | saint-joseph
# Processing Record 43 of Set 6 | balmullo
# Processing Record 44 of Set 6 | chuy
# Processing Record 45 of Set 6 | kirakira
# Processing Record 46 of Set 6 | san patricio
# Processing Record 47 of Set 6 | south river
# Processing Record 48 of Set 6 | batemans bay
# Processing Record 49 of Set 6 | bonavista
# Processing Record 50 of Set 6 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 1 of Set 7 | marovoay
# Processing Record 2 of Set 7 | souillac
# Processing Record 3 of Set 7 | asfi
# Processing Record 4 of Set 7 | katsuura
# Processing Record 5 of Set 7 | marawi
# Processing Record 6 of Set 7 | puerto baquerizo moreno
# Processing Record 7 of Set 7 | nizhniy ufaley
# Processing Record 8 of Set 7 | gallup
# Processing Record 9 of Set 7 | pedernales
# Processing Record 10 of Set 7 | kavieng
# Processing Record 11 of Set 7 | komsomolskiy
# Processing Record 12 of Set 7 | leningradskiy
# Processing Record 13 of Set 7 | ridgecrest
# Processing Record 14 of Set 7 | moerai
# Processing Record 15 of Set 7 | ulladulla
# Processing Record 16 of Set 7 | matara
# Processing Record 17 of Set 7 | kaniama
# Processing Record 18 of Set 7 | namie
# Processing Record 19 of Set 7 | correntina
# Processing Record 20 of Set 7 | pangnirtung
# Processing Record 21 of Set 7 | mount gambier
# Processing Record 22 of Set 7 | bull savanna
# Processing Record 23 of Set 7 | turbat
# Processing Record 24 of Set 7 | deep river
# Processing Record 25 of Set 7 | nanortalik
# Processing Record 26 of Set 7 | ponta do sol
# Processing Record 27 of Set 7 | bambous virieux
# Processing Record 28 of Set 7 | baglan
# Processing Record 29 of Set 7 | havelock
# Processing Record 30 of Set 7 | rocha
# Processing Record 31 of Set 7 | balykshi
# Processing Record 32 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 33 of Set 7 | chara
# Processing Record 34 of Set 7 | husavik
# Processing Record 35 of Set 7 | progreso
# Processing Record 36 of Set 7 | puerto escondido
# Processing Record 37 of Set 7 | grand gaube
# Processing Record 38 of Set 7 | mount isa
# Processing Record 39 of Set 7 | purpe
# Processing Record 40 of Set 7 | yar-sale
# Processing Record 41 of Set 7 | tangjiazhuang
# Processing Record 42 of Set 7 | na wa
# Processing Record 43 of Set 7 | fortuna
# Processing Record 44 of Set 7 | bumba
# Processing Record 45 of Set 7 | maiduguri
# Processing Record 46 of Set 7 | gat
# Processing Record 47 of Set 7 | beringovskiy
# Processing Record 48 of Set 7 | lemesos
# City not found. Skipping...
# Processing Record 49 of Set 7 | honningsvag
# Processing Record 50 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 1 of Set 8 | gobardanga
# Processing Record 2 of Set 8 | dolbeau
# City not found. Skipping...
# Processing Record 3 of Set 8 | meulaboh
# Processing Record 4 of Set 8 | teruel
# Processing Record 5 of Set 8 | lorengau
# Processing Record 6 of Set 8 | morrope
# Processing Record 7 of Set 8 | gorontalo
# Processing Record 8 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 9 of Set 8 | bilma
# Processing Record 10 of Set 8 | tuatapere
# Processing Record 11 of Set 8 | marquette
# Processing Record 12 of Set 8 | revda
# Processing Record 13 of Set 8 | narsaq
# Processing Record 14 of Set 8 | ponta delgada
# Processing Record 15 of Set 8 | najran
# Processing Record 16 of Set 8 | varzea alegre
# Processing Record 17 of Set 8 | pouembout
# Processing Record 18 of Set 8 | yerbogachen
# Processing Record 19 of Set 8 | xingyi
# Processing Record 20 of Set 8 | maniitsoq
# Processing Record 21 of Set 8 | san juan
# Processing Record 22 of Set 8 | faya
# Processing Record 23 of Set 8 | kambove
# Processing Record 24 of Set 8 | sao miguel do araguaia
# Processing Record 25 of Set 8 | tessalit
# Processing Record 26 of Set 8 | bengkulu
# Processing Record 27 of Set 8 | kariba
# Processing Record 28 of Set 8 | kachug
# Processing Record 29 of Set 8 | ulagan
# Processing Record 30 of Set 8 | liberal
# Processing Record 31 of Set 8 | yaan
# Processing Record 32 of Set 8 | lompoc
# Processing Record 33 of Set 8 | champerico
# Processing Record 34 of Set 8 | rakke
# Processing Record 35 of Set 8 | santa cruz
# Processing Record 36 of Set 8 | muros
# Processing Record 37 of Set 8 | blagoyevo
# Processing Record 38 of Set 8 | dingle
# Processing Record 39 of Set 8 | bocas del toro
# Processing Record 40 of Set 8 | mayor pablo lagerenza
# Processing Record 41 of Set 8 | ruatoria
# City not found. Skipping...
# Processing Record 42 of Set 8 | nelson bay
# Processing Record 43 of Set 8 | aktanysh
# Processing Record 44 of Set 8 | alferrarede
# Processing Record 45 of Set 8 | marki
# Processing Record 46 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 47 of Set 8 | coquimbo
# Processing Record 48 of Set 8 | olinda
# Processing Record 49 of Set 8 | buala
# Processing Record 50 of Set 8 | modrica
# Processing Record 1 of Set 9 | quzhou
# Processing Record 2 of Set 9 | pacific grove
# Processing Record 3 of Set 9 | deyang
# Processing Record 4 of Set 9 | toora-khem
# Processing Record 5 of Set 9 | adrar
# Processing Record 6 of Set 9 | koroni
# Processing Record 7 of Set 9 | kibala
# Processing Record 8 of Set 9 | guane
# Processing Record 9 of Set 9 | chifeng
# Processing Record 10 of Set 9 | tawkar
# City not found. Skipping...
# Processing Record 11 of Set 9 | kintinku
# Processing Record 12 of Set 9 | del carmen
# Processing Record 13 of Set 9 | jefferson city
# Processing Record 14 of Set 9 | puerto narino
# Processing Record 15 of Set 9 | calama
# Processing Record 16 of Set 9 | dzilam gonzalez
# Processing Record 17 of Set 9 | port hedland
# Processing Record 18 of Set 9 | nagareyama
# Processing Record 19 of Set 9 | launceston
# Processing Record 20 of Set 9 | yumen
# Processing Record 21 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 22 of Set 9 | cepu
# Processing Record 23 of Set 9 | hirado
# Processing Record 24 of Set 9 | druskininkai
# Processing Record 25 of Set 9 | calvinia
# Processing Record 26 of Set 9 | catamarca
# Processing Record 27 of Set 9 | cam ranh
# Processing Record 28 of Set 9 | san quintin
# Processing Record 29 of Set 9 | mayo
# Processing Record 30 of Set 9 | camapua
# Processing Record 31 of Set 9 | kaithal
# Processing Record 32 of Set 9 | goundam
# Processing Record 33 of Set 9 | ancud
# Processing Record 34 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 35 of Set 9 | chalisgaon
# Processing Record 36 of Set 9 | huanren
# Processing Record 37 of Set 9 | zaltan
# Processing Record 38 of Set 9 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 39 of Set 9 | ketchikan
# Processing Record 40 of Set 9 | vao
# Processing Record 41 of Set 9 | batticaloa
# Processing Record 42 of Set 9 | dong hoi
# Processing Record 43 of Set 9 | qarayeri
# Processing Record 44 of Set 9 | kazachinskoye
# Processing Record 45 of Set 9 | ugoofaaru
# Processing Record 46 of Set 9 | guayaramerin
# Processing Record 47 of Set 9 | vila
# Processing Record 48 of Set 9 | la ferte-bernard
# Processing Record 49 of Set 9 | saint anthony
# Processing Record 50 of Set 9 | hauterive
# Processing Record 1 of Set 10 | soyo
# Processing Record 2 of Set 10 | lapus
# Processing Record 3 of Set 10 | kropotkin
# Processing Record 4 of Set 10 | udachnyy
# Processing Record 5 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 6 of Set 10 | wanning
# Processing Record 7 of Set 10 | nemuro
# Processing Record 8 of Set 10 | gornopravdinsk
# Processing Record 9 of Set 10 | lagoa
# Processing Record 10 of Set 10 | zhigansk
# Processing Record 11 of Set 10 | riyadh
# Processing Record 12 of Set 10 | pudozh
# Processing Record 13 of Set 10 | divnoye
# Processing Record 14 of Set 10 | oga
# Processing Record 15 of Set 10 | cortez
# Processing Record 16 of Set 10 | concordia
# Processing Record 17 of Set 10 | kawalu
# Processing Record 18 of Set 10 | angra dos reis
# Processing Record 19 of Set 10 | gravdal
# Processing Record 20 of Set 10 | gulshat
# City not found. Skipping...
# Processing Record 21 of Set 10 | shache
# Processing Record 22 of Set 10 | gargzdai
# Processing Record 23 of Set 10 | qaqortoq
# Processing Record 24 of Set 10 | erenhot
# Processing Record 25 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 26 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 27 of Set 10 | yokosuka
# Processing Record 28 of Set 10 | dharmavaram
# Processing Record 29 of Set 10 | neryungri
# Processing Record 30 of Set 10 | vila do maio
# Processing Record 31 of Set 10 | taltal
# Processing Record 32 of Set 10 | turukhansk
# Processing Record 33 of Set 10 | hami
# Processing Record 34 of Set 10 | beitbridge
# Processing Record 35 of Set 10 | tanout
# Processing Record 36 of Set 10 | sinaloa
# Processing Record 37 of Set 10 | tigil
# Processing Record 38 of Set 10 | potgietersrus
# City not found. Skipping...
# Processing Record 39 of Set 10 | piacabucu
# Processing Record 40 of Set 10 | nguruka
# Processing Record 41 of Set 10 | makakilo city
# Processing Record 42 of Set 10 | ghioroc
# Processing Record 43 of Set 10 | andevoranto
# City not found. Skipping...
# Processing Record 44 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 45 of Set 10 | sept-iles
# Processing Record 46 of Set 10 | krasnoselkup
# Processing Record 47 of Set 10 | hede
# Processing Record 48 of Set 10 | naze
# Processing Record 49 of Set 10 | eyl
# Processing Record 50 of Set 10 | moville
# Processing Record 1 of Set 11 | karpathos
# Processing Record 2 of Set 11 | arang
# Processing Record 3 of Set 11 | presidencia roque saenz pena
# Processing Record 4 of Set 11 | hovd
# Processing Record 5 of Set 11 | tapaua
# City not found. Skipping...
# Processing Record 6 of Set 11 | rio gallegos
# Processing Record 7 of Set 11 | dzhusaly
# City not found. Skipping...
# Processing Record 8 of Set 11 | henties bay
# Processing Record 9 of Set 11 | brigantine
# Processing Record 10 of Set 11 | naantali
# Processing Record 11 of Set 11 | severomuysk
# Processing Record 12 of Set 11 | damavand
# Processing Record 13 of Set 11 | ust-maya
# Processing Record 14 of Set 11 | naifaru
# Processing Record 15 of Set 11 | surt
# Processing Record 16 of Set 11 | flin flon
# Processing Record 17 of Set 11 | notse
# Processing Record 18 of Set 11 | rio verde de mato grosso
# Processing Record 19 of Set 11 | tabas
# Processing Record 20 of Set 11 | saint-pierre
# Processing Record 21 of Set 11 | hamilton
# Processing Record 22 of Set 11 | ozgon
# City not found. Skipping...
# Processing Record 23 of Set 11 | kaspiyskiy
# Processing Record 24 of Set 11 | havoysund
# Processing Record 25 of Set 11 | kangaba
# Processing Record 26 of Set 11 | iskateley
# Processing Record 27 of Set 11 | tallahassee
# Processing Record 28 of Set 11 | naples
# Processing Record 29 of Set 11 | alashtar
# City not found. Skipping...
# Processing Record 30 of Set 11 | jahrom
# City not found. Skipping...
# Processing Record 31 of Set 11 | mwinilunga
# Processing Record 32 of Set 11 | terney
# Processing Record 33 of Set 11 | bariri
# Processing Record 34 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 35 of Set 11 | vila franca do campo
# Processing Record 36 of Set 11 | palmer
# Processing Record 37 of Set 11 | khandyga
# Processing Record 38 of Set 11 | thap than
# Processing Record 39 of Set 11 | baruun-urt
# Processing Record 40 of Set 11 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 41 of Set 11 | ola
# Processing Record 42 of Set 11 | portland
# Processing Record 43 of Set 11 | choma
# Processing Record 44 of Set 11 | mitsamiouli
# Processing Record 45 of Set 11 | saldanha
# Processing Record 46 of Set 11 | puerto carreno
# Processing Record 47 of Set 11 | rong kwang
# Processing Record 48 of Set 11 | chicama
# Processing Record 49 of Set 11 | kungurtug
# Processing Record 50 of Set 11 | labuhan
# Processing Record 1 of Set 12 | ambulu
# Processing Record 2 of Set 12 | urulga
# City not found. Skipping...
# Processing Record 3 of Set 12 | alta floresta
# Processing Record 4 of Set 12 | morwell
# Processing Record 5 of Set 12 | nouadhibou
# Processing Record 6 of Set 12 | puri
# Processing Record 7 of Set 12 | bukit bakri
# City not found. Skipping...
# Processing Record 8 of Set 12 | celestun
# Processing Record 9 of Set 12 | acajutla
# Processing Record 10 of Set 12 | tuy hoa
# Processing Record 11 of Set 12 | zavyalovo
# Processing Record 12 of Set 12 | waipawa
# Processing Record 13 of Set 12 | santa vitoria do palmar
# Processing Record 14 of Set 12 | gualaquiza
# Processing Record 15 of Set 12 | kazalinsk
# City not found. Skipping...
# Processing Record 16 of Set 12 | ajdabiya
# Processing Record 17 of Set 12 | vanimo
# Processing Record 18 of Set 12 | zhezkazgan
# Processing Record 19 of Set 12 | motygino
# Processing Record 20 of Set 12 | gazojak
# Processing Record 21 of Set 12 | kundian
# Processing Record 22 of Set 12 | sur
# Processing Record 23 of Set 12 | huejuquilla el alto
# Processing Record 24 of Set 12 | luganville
# Processing Record 25 of Set 12 | ornskoldsvik
# Processing Record 26 of Set 12 | mao
# Processing Record 27 of Set 12 | diego de almagro
# Processing Record 28 of Set 12 | korla
# Processing Record 29 of Set 12 | nouakchott
# Processing Record 30 of Set 12 | amarante do maranhao
# Processing Record 31 of Set 12 | alghero
# Processing Record 32 of Set 12 | bontang
# Processing Record 33 of Set 12 | tynda
# Processing Record 34 of Set 12 | guerrero negro
# Processing Record 35 of Set 12 | vrangel
# Processing Record 36 of Set 12 | zaraza
# Processing Record 37 of Set 12 | zeya
# Processing Record 38 of Set 12 | limot
# Processing Record 39 of Set 12 | quelimane
# Processing Record 40 of Set 12 | beloha
# Processing Record 41 of Set 12 | necochea
# Processing Record 42 of Set 12 | glenwood springs
# Processing Record 43 of Set 12 | touros
# Processing Record 44 of Set 12 | boyolangu
# Processing Record 45 of Set 12 | sunamganj
# City not found. Skipping...
# Processing Record 46 of Set 12 | sambava
# Processing Record 47 of Set 12 | khovu-aksy
# Processing Record 48 of Set 12 | isla vista
# Processing Record 49 of Set 12 | tual
# Processing Record 50 of Set 12 | mana
# Processing Record 1 of Set 13 | goma
# Processing Record 2 of Set 13 | clifton
# Processing Record 3 of Set 13 | sawtell
# Processing Record 4 of Set 13 | flagstaff
# Processing Record 5 of Set 13 | clarence town
# Processing Record 6 of Set 13 | porgera
# Processing Record 7 of Set 13 | robat karim
# Processing Record 8 of Set 13 | yerofey pavlovich
# Processing Record 9 of Set 13 | cobija
# Processing Record 10 of Set 13 | koslan
# Processing Record 11 of Set 13 | shadegan
# Processing Record 12 of Set 13 | poya
# Processing Record 13 of Set 13 | auriflama
# Processing Record 14 of Set 13 | tayu
# Processing Record 15 of Set 13 | ahuimanu
# Processing Record 16 of Set 13 | borujan
# City not found. Skipping...
# Processing Record 17 of Set 13 | saurimo
# Processing Record 18 of Set 13 | severo-yeniseyskiy
# Processing Record 19 of Set 13 | zhireken
# Processing Record 20 of Set 13 | mandal
# Processing Record 21 of Set 13 | mendeleyevsk
# Processing Record 22 of Set 13 | belaya gora
# Processing Record 23 of Set 13 | schwerin
# Processing Record 24 of Set 13 | savasleyka
# Processing Record 25 of Set 13 | baft
# Processing Record 26 of Set 13 | grosseto
# Processing Record 27 of Set 13 | sayyan
# Processing Record 28 of Set 13 | camana
# Processing Record 29 of Set 13 | odesskoye
# Processing Record 30 of Set 13 | salinopolis
# Processing Record 31 of Set 13 | halifax
# Processing Record 32 of Set 13 | berlevag
# Processing Record 33 of Set 13 | santa marta
# Processing Record 34 of Set 13 | honolulu
# Processing Record 35 of Set 13 | narasannapeta
# Processing Record 36 of Set 13 | tehachapi
# Processing Record 37 of Set 13 | klaksvik
# Processing Record 38 of Set 13 | camabatela
# Processing Record 39 of Set 13 | puerto leguizamo
# Processing Record 40 of Set 13 | high level
# Processing Record 41 of Set 13 | tingi
# Processing Record 42 of Set 13 | great yarmouth
# Processing Record 43 of Set 13 | upanema
# Processing Record 44 of Set 13 | drumheller
# Processing Record 45 of Set 13 | sao raimundo nonato
# Processing Record 46 of Set 13 | zhangjiakou
# Processing Record 47 of Set 13 | barao de melgaco
# Processing Record 48 of Set 13 | kadykchan
# City not found. Skipping...
# Processing Record 49 of Set 13 | norrtalje
# Processing Record 50 of Set 13 | coalcoman
# City not found. Skipping...
# Processing Record 1 of Set 14 | jacareacanga
# Processing Record 2 of Set 14 | mackay
# Processing Record 3 of Set 14 | aviles
# Processing Record 4 of Set 14 | san vicente
# Processing Record 5 of Set 14 | stepnyak
# Processing Record 6 of Set 14 | port hawkesbury
# Processing Record 7 of Set 14 | college
# Processing Record 8 of Set 14 | san jeronimo
# Processing Record 9 of Set 14 | bataraza
# City not found. Skipping...
# Processing Record 10 of Set 14 | chateaubelair
# Processing Record 11 of Set 14 | karratha
# Processing Record 12 of Set 14 | touba
# Processing Record 13 of Set 14 | uk
# City not found. Skipping...
# Processing Record 14 of Set 14 | moose factory
# Processing Record 15 of Set 14 | warah
# Processing Record 16 of Set 14 | okahandja
# Processing Record 17 of Set 14 | bati
# Processing Record 18 of Set 14 | grand centre
# City not found. Skipping...
# Processing Record 19 of Set 14 | port dickson
# Processing Record 20 of Set 14 | pulandian
# Processing Record 21 of Set 14 | kakrala
# Processing Record 22 of Set 14 | tombouctou
# Processing Record 23 of Set 14 | lupiro
# Processing Record 24 of Set 14 | tucuman
# Processing Record 25 of Set 14 | sibolga
# Processing Record 26 of Set 14 | hohhot
# Processing Record 27 of Set 14 | waw
# Processing Record 28 of Set 14 | coxim
# Processing Record 29 of Set 14 | ambilobe
# Processing Record 30 of Set 14 | broome
# Processing Record 31 of Set 14 | gizo
# Processing Record 32 of Set 14 | poltavka
# Processing Record 33 of Set 14 | qinhuangdao
# Processing Record 34 of Set 14 | abu samrah
# Processing Record 35 of Set 14 | carinhanha
# Processing Record 36 of Set 14 | salalah
# Processing Record 37 of Set 14 | san buenaventura
# Processing Record 38 of Set 14 | sao jose da coroa grande
# Processing Record 39 of Set 14 | kedrovyy
# Processing Record 40 of Set 14 | santa maria
# Processing Record 41 of Set 14 | nguiu
# City not found. Skipping...
# Processing Record 42 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 43 of Set 14 | russell
# Processing Record 44 of Set 14 | hima
# Processing Record 45 of Set 14 | saint-leu
# Processing Record 46 of Set 14 | neiafu
# Processing Record 47 of Set 14 | debre tabor
# Processing Record 48 of Set 14 | praia
# Processing Record 49 of Set 14 | fallon
# Processing Record 50 of Set 14 | porto novo
# Processing Record 1 of Set 15 | preston
# Processing Record 2 of Set 15 | marietta
# Processing Record 3 of Set 15 | loubomo
# Processing Record 4 of Set 15 | tomari
# Processing Record 5 of Set 15 | inhambane
# Processing Record 6 of Set 15 | kyaukse
# Processing Record 7 of Set 15 | laramie
# Processing Record 8 of Set 15 | achit
# Processing Record 9 of Set 15 | bantry
# Processing Record 10 of Set 15 | manta
# Processing Record 11 of Set 15 | fairhope
# Processing Record 12 of Set 15 | hojai
# Processing Record 13 of Set 15 | panjwin
# City not found. Skipping...
# Processing Record 14 of Set 15 | ateli
# Processing Record 15 of Set 15 | opuwo
# Processing Record 16 of Set 15 | kawana waters
# City not found. Skipping...
# Processing Record 17 of Set 15 | barcelos
# Processing Record 18 of Set 15 | staroaleyskoye
# Processing Record 19 of Set 15 | micheweni
# Processing Record 20 of Set 15 | pierre
# Processing Record 21 of Set 15 | frei paulo
# Processing Record 22 of Set 15 | belmopan
# Processing Record 23 of Set 15 | prabumulih
# Processing Record 24 of Set 15 | hualmay
# Processing Record 25 of Set 15 | dinghai
# Processing Record 26 of Set 15 | wagar
# Processing Record 27 of Set 15 | peniche
# Processing Record 28 of Set 15 | magdalena
# Processing Record 29 of Set 15 | teguldet
# Processing Record 30 of Set 15 | zavodoukovsk
# Processing Record 31 of Set 15 | waiuku
# Processing Record 32 of Set 15 | mhlume
# Processing Record 33 of Set 15 | okitipupa
# Processing Record 34 of Set 15 | vardo
# Processing Record 35 of Set 15 | dabat
# Processing Record 36 of Set 15 | kaeo
# Processing Record 37 of Set 15 | biak
# Processing Record 38 of Set 15 | abha
# Processing Record 39 of Set 15 | hayvoron
# Processing Record 40 of Set 15 | norfolk
# Processing Record 41 of Set 15 | pimentel
# Processing Record 42 of Set 15 | teya
# Processing Record 43 of Set 15 | csabrendek
# Processing Record 44 of Set 15 | half moon bay
# Processing Record 45 of Set 15 | isla mujeres
# Processing Record 46 of Set 15 | am timan
# Processing Record 47 of Set 15 | bambanglipuro
# Processing Record 48 of Set 15 | bushehr
# Processing Record 49 of Set 15 | khani
# Processing Record 50 of Set 15 | baloda bazar
# Processing Record 1 of Set 16 | pontianak
# Processing Record 2 of Set 16 | naryan-mar
# Processing Record 3 of Set 16 | kayerkan
# Processing Record 4 of Set 16 | san cristobal
# Processing Record 5 of Set 16 | chadiza
# Processing Record 6 of Set 16 | voi
# Processing Record 7 of Set 16 | san jose
# Processing Record 8 of Set 16 | petropavlovka
# Processing Record 9 of Set 16 | lipari
# Processing Record 10 of Set 16 | mecca
# Processing Record 11 of Set 16 | lukulu
# Processing Record 12 of Set 16 | omboue
# Processing Record 13 of Set 16 | tiznit
# Processing Record 14 of Set 16 | vanavara
# Processing Record 15 of Set 16 | mahon
# Processing Record 16 of Set 16 | rovaniemi
# Processing Record 17 of Set 16 | alofi
# Processing Record 18 of Set 16 | sisimiut
# Processing Record 19 of Set 16 | san jose de ocoa
# Processing Record 20 of Set 16 | okhotsk
# Processing Record 21 of Set 16 | dryden
# Processing Record 22 of Set 16 | sioux lookout
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#              City  Cloudiness Country Current Description  Humidity      Lat  \
# 0  Ribeira Grande           3      PT           clear sky        92  38.5167
# 1         Samarai          98      PG     overcast clouds        83 -10.6167
# 2      Novoagansk         100      RU     overcast clouds        91  61.9449
# 3       Caravelas           2      BR           clear sky        64 -17.7125
# 4       Kavaratti          89      IN     overcast clouds        78  10.5669
#
#         Lng  Max Temp  Wind Speed
# 0  -28.7000     70.45        8.77
# 1  150.6667     79.95       15.30
# 2   76.6625     59.32        6.17
# 3  -39.2481     69.69        6.40
# 4   72.6420     81.99       20.80

# %%
city_data_df.to_csv('WeatherPy_Database.csv',index=False)
